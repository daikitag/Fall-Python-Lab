# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/data.csv')

# %%
df
# Out:
#           SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0      93703.0      10.0       2.0       2.0       2.0       NaN       5.0
# 1      93704.0      10.0       2.0       1.0       2.0       NaN       3.0
# 2      93705.0      10.0       2.0       2.0      66.0       NaN       4.0
# 3      93706.0      10.0       2.0       1.0      18.0       NaN       5.0
# 4      93707.0      10.0       2.0       1.0      13.0       NaN       5.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 9249  102952.0      10.0       2.0       2.0      70.0       NaN       5.0
# 9250  102953.0      10.0       2.0       1.0      42.0       NaN       1.0
# 9251  102954.0      10.0       2.0       2.0      41.0       NaN       4.0
# 9252  102955.0      10.0       2.0       2.0      14.0       NaN       4.0
# 9253  102956.0      10.0       2.0       1.0      38.0       NaN       3.0
#
# ...

# %% [markdown]
# These column names are difficult to see, and the following table describes the name of these variables.

# %% [markdown]
# <table>
#   <tr>
#     <th>Variable Name</th>
#     <th>Variable Description</th>
#   </tr>
#   <tr>
#     <td>DMDEDUC2</td>
#     <td>What is the highest grade or level of school {you have/SP has} completed or the highest degree {you have/s/he has} received?</td>
#   </tr>
#   <tr>
#     <td>DMDHHSIZ</td>
#     <td>Total number of people in the Household</td>
#   </tr>
#   <tr>
#       <td>INDFMIN2</td>
#       <td>Total family income (reported as a range value in dollars)</td>
#     </tr>
#     <tr>
#         <td>INDFMPIR</td>
#         <td>A ratio of family income to poverty guidelines.</td>
#     </tr>
#     <tr>
#         <td>INDHHIN2</td>
#         <td>Total household income (reported as a range value in dollars)</td>
#     </tr>
#     <tr>
#         <td>RIDRETH3</td>
#         <td>Recode of reported race and Hispanic origin information, with Non-Hispanic Asian Category</td>
#     </tr>
#     <tr>
#         <td>WTMEC2YR</td>
#         <td>Full sample 2 year MEC exam weight.</td>
#     </tr>
#     <tr>
#         <td>SEQN</td>
#         <td>Respondent sequence number</td>
#     </tr>
# </table>

# %%
np.mean(df['WTMEC2YR'])
# Out:
# 34670.706829479146
